# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import requests

# %%
driver = webdriver.Chrome("C:/algorithm/chromedriver/chromedriver")
url = "https://www.melon.com/chart/index.htm"

driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
song_data = []
rank = 1

songs = soup.select('table > tbody > tr')
for song in songs:
    title = song.select('div.rank01 > span > a')[0].text
    singer = song.select('div.rank02 > a')[0].text
    song_data.append(['melon', rank, title, singer])
    rank = rank+1

# %%
import pandas as pd
columns = ['서비스', '순위', '타이틀', '가수']
pd_data = pd.DataFrame(song_data, columns = columns)
pd_data.head()
# Out:
#      서비스  순위            타이틀                 가수
# 0  melon   1            신호등                이무진
# 1  melon   2         바라만 본다      MSG워너비(M.O.M)
# 2  melon   3     Next Level              aespa
# 3  melon   4       Queendom  Red Velvet (레드벨벳)
# 4  melon   5  낙하 (with 아이유)          AKMU (악뮤)

# %%
pd_data.to_excel('C:/algorithm/melon.xlsx', index = False)

# %%
driver = webdriver.Chrome('C:/algorithm/chromedriver/chromedriver')
url = "https://music.bugs.co.kr/chart"
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
songs1 = soup.select('tr')
print(len(songs))
# Out:
# 100

# %%
songs1 = soup.select('tbody>tr')
print(len(songs1))
# Out:
# 103

# %%
songs1 = soup.select('table>tbody>tr')
print(len(songs1))
# Out:
# 103

# %%
songs1 = soup.select('table.byChart>tbody>tr')
print(len(songs1))
# Out:
# 100

# %%
print(songs1[0])
# Out:
# <tr albumid="20415229" artistid="80199440" multiartist="N" mvid="601660" rowtype="track" trackid="32312152">
# <input name="_isStream" type="hidden" value="32312152"/>
# <input name="_isDown" type="hidden" value="32312152"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Queendom" type="checkbox" value="32312152"/></td>
# <td>
# <div class="ranking">
# <strong>1</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/20415229?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="Queendom - The 6th Mini Album 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/204152/20415229.jpg?version=20210818004552.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/32312152?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# ...

# %%
song = songs1[0]

# %%
title = song.select('a')
len(title)
# Out:
# 11

# %%
title = song.select('p.title>a')
len(title)
# Out:
# 1

# %%
title = song.select('p>a')
len(title)
# Out:
# 2

# %%
title = song.select('p.title>a')[0].text
title
# Out:
# 'Queendom'

# %%
singer = song.select('p.artist>a')[0].text.strip()
singer
# Out:
# 'Red Velvet (레드벨벳)'

# %%
songs1 = soup.select('table.byChart>tbody>tr')
for song in songs1:
    title = song.select('p.title>a')[0].text
    singer = song.select('p.artist>a')[0].text
    print(title, singer, sep = '|')
# Out:
# Queendom|Red Velvet (레드벨벳)
# STAY|The Kid LAROI
# DUMB DUMB|전소미
# 낙하 (with 아이유)|AKMU(악뮤)
# 신호등|이무진
# Weekend|태연 (TAEYEON)
# Next Level|aespa
# Permission to Dance|방탄소년단
# 회상|정경호
# OHAYO MY NIGHT|디핵(D-Hack)
# 여전히 아름다운지|세븐틴(SEVENTEEN)
# 비가 오는 날엔 (2021)|헤이즈(Heize)
# 바라만 본다|MSG워너비(M.O.M)
# 좋아좋아|조정석
# Butter|방탄소년단
# 사진을 보다가|다비치
# Bad Habits|Ed Sheeran(에드 시런)
# Peaches (feat. Daniel Caesar, Giveon)|Justin Bieber(저스틴 비버)
# 고백|10CM
# 제자리 걸음|V.O.S.
# You can't sit with us|선미
# Alcohol-Free|TWICE (트와이스)
# 벌써 일년 (Drama Ver.)|미도와 파라솔
# 비와 당신|이무진
# 다정히 내 이름을 부르면|경서예지
# 고백|장범준
# 라일락|아이유(IU)
# Dun Dun Dance|오마이걸(OH MY GIRL)
# ASAP|STAYC(스테이씨)
# 슈퍼스타|미도와 파라솔
# 헤픈 우연|헤이즈(Heize)
# Dynamite|방탄소년단
# 롤린 (Rollin')|브레이브걸스(Brave Girls)
# 하루만 더|빅마마(Big Mama)
# 이젠 잊기로 해요 (Drama Ver.)|미도와 파라솔
# 비 오는 날 듣기 좋은 노래 (Feat. Colde)|에픽하이 (EPIK HIGH)
# 치맛바람 (Chi Mat Ba Ram)|브레이브걸스(Brave Girls)
# Celebrity|아이유(IU)
# Pose|Red Velvet (레드벨벳)
# 전쟁터 (with 이선희)|AKMU(악뮤)
# 안녕 (Hello)|조이 (JOY)
# ...

# %%
song_data1 = []
rank = 1
songs1 = soup.select('table.byChart > tbody > tr')
for song in songs1:
    title = song.select('p.title>a')[0].text
    singer = song.select('p.artist>a')[0].text
    song_data1.append(['Bugs', rank, title, singer])
    rank = rank+1

# %%
import pandas as pd
columns = ['서비스', '순위', '타이틀', '가수']
pd_data1 = pd.DataFrame(song_data1, columns = columns)
pd_data1
# Out:
#      서비스   순위                         타이틀                 가수
# 0   Bugs    1                    Queendom  Red Velvet (레드벨벳)
# 1   Bugs    2                        STAY      The Kid LAROI
# 2   Bugs    3                   DUMB DUMB                전소미
# 3   Bugs    4               낙하 (with 아이유)           AKMU(악뮤)
# 4   Bugs    5                         신호등                이무진
# ..   ...  ...                         ...                ...
# 95  Bugs   96     EVEREST (with Sam Kim)            AKMU(악뮤)
# 96  Bugs   97                         밤편지            아이유(IU)
# 97  Bugs   98                다시 사랑할 수 있을까                백지영
# 98  Bugs   99  둘 중에 골라 (Summer or Summer)                 효린
# 99  Bugs  100   Dive with you (feat. eaJ)              Seori
#
# [100 rows x 4 columns]

# %%
pd_data1.to_excel('C:/algorithm/bugs1.xlsx', index = False)

# %%
driver = webdriver.Chrome('C:/algorithm/chromedriver/chromedriver')
url = 'https:/genie.co.kr/chart/top200'
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
songs = soup.select('table > tbody > tr')
len(songs)
# Out:
# 50

# %%
print(songs[0])
# Out:
# <tr class="list" songid="93717294">
# <td class="check"><input class="select-check" title="Stay" type="checkbox"/></td>
# <td class="number">1
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82130513');return false;"><span class="mask"></span><img alt="Stay" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/130/513/82130513_1625722837604_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('93717294');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('93717294','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Stay</a>
# ...

# %%
song = songs[0]

# %%
title = song.select('a.title')
len(title)
# Out:
# 1

# %%
title = song.select('a.title')[0].text
title
# Out:
# '\n                                        \n                                            \n                                        \n                                        \n                                        \n                                        \n                                            \n                                                Stay'

# %%
title = song.select('a.title')[0].text.strip()
title
# Out:
# 'Stay'

# %%
singer = song.select('a.artist')[0].text
singer
# Out:
# 'The Kid LAROI & Justin Bieber'

# %%
songs = soup.select('tbody > tr')
for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()
    print(title, singer, sep = '|')
# Out:
# Stay|The Kid LAROI & Justin Bieber
# 신호등|이무진
# Queendom|Red Velvet (레드벨벳)
# OHAYO MY NIGHT|디핵 (D-Hack) & PATEKO
# 낙하 (With 아이유)|AKMU (악뮤)
# 바라만 본다|MSG워너비 (M.O.M)
# Next Level|aespa
# DUMB DUMB|전소미
# Weekend|태연 (TAEYEON)
# Permission to Dance|방탄소년단
# Bad Habits|Ed Sheeran
# 좋아좋아|조정석
# Butter|방탄소년단
# 사진을 보다가|다비치
# 이제 나만 믿어요|임영웅
# 비와 당신|이무진
# Peaches (Feat. Daniel Caesar & Giveon)|Justin Bieber
# 비가 오는 날엔 (2021)|헤이즈 (Heize)
# 다시 사랑한다면 (김필 Ver.)|임영웅
# 헤픈 우연|헤이즈 (Heize)
# 별빛 같은 나의 사랑아|임영웅
# 다정히 내 이름을 부르면|경서예지 & 전건호
# Dynamite|방탄소년단
# HERO|임영웅
# 그대라는 사치|임영웅
# 끝사랑|임영웅
# Bk Love|임영웅
# 고백|10CM
# 잊었니|임영웅
# 롤린 (Rollin')|브레이브걸스 (Brave girls)
# 미워요|임영웅
# 하루만 더|빅마마 (Big Mama)
# Dun Dun Dance|오마이걸 (OH MY GIRL)
# 사랑의 아픔 딛고|임영웅
# 라일락|아이유 (IU)
# 여전히 아름다운지|세븐틴 (SEVENTEEN)
# 계단말고 엘리베이터|임영웅
# 네 노래|피아노맨
# 비 오는 날 듣기 좋은 노래 (Feat. Colde)|에픽하이 (EPIK HIGH)
# 치맛바람 (Chi Mat Ba Ram)|브레이브걸스 (Brave girls)
# 목로주점|임영웅
# Savage Love (Laxed - Siren Beat) (BTS Remix)|Jawsh 685 & Jason Derulo & 방탄소년단
# ...

# %%
song_data = []
rank =1
songs = soup.select('table > tbody > tr')
for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text
    song_data.append(['Genie', rank, title, singer])
    rank = rank +1

# %%
import pandas as pd

columns = ['서비스', '순위', '타이틀', '가수']
pd_data = pd.DataFrame(song_data, columns = columns)
pd_data.to_excel('C:/algorithm/genie.xlsx', index = False)

# %%
pd_data
# Out:
#       서비스  순위                                             타이틀  \
# 0   Genie   1                                            Stay
# 1   Genie   2                                             신호등
# 2   Genie   3                                        Queendom
# 3   Genie   4                                  OHAYO MY NIGHT
# 4   Genie   5                                   낙하 (With 아이유)
# 5   Genie   6                                          바라만 본다
# 6   Genie   7                                      Next Level
# 7   Genie   8                                       DUMB DUMB
# 8   Genie   9                                         Weekend
# 9   Genie  10                             Permission to Dance
# 10  Genie  11                                      Bad Habits
# 11  Genie  12                                            좋아좋아
# 12  Genie  13                                          Butter
# 13  Genie  14                                         사진을 보다가
# ...

# %%
excel_names = ['C:/algorithm/melon.xlsx','C:/algorithm/bugs1.xlsx', 'C:/algorithm/genie.xlsx']

appended_data = pd.DataFrame()
for name in excel_names:
    pd_data = pd.read_excel(name)
    appended_data = appended_data.append(pd_data)

# %%
appended_data
# Out:
#       서비스  순위                                             타이틀  \
# 0   melon   1                                             신호등
# 1   melon   2                                          바라만 본다
# 2   melon   3                                      Next Level
# 3   melon   4                                        Queendom
# 4   melon   5                                   낙하 (with 아이유)
# ..    ...  ..                                             ...
# 45  Genie  46                                              회상
# 46  Genie  47  사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
# 47  Genie  48                                      가을 우체국 앞에서
# 48  Genie  49                                            ASAP
# 49  Genie  50                                  운전만해 (We Ride)
#
#                       가수
# 0                    이무진
# 1          MSG워너비(M.O.M)
# 2                  aespa
# 3      Red Velvet (레드벨벳)
# 4              AKMU (악뮤)
# ..                   ...
# 45                   정경호
# ...

# %%
appended_data.to_excel('C:/algorithm/total.xlsx', index=False)
